# %%
pip install diffusers transformers opencv-python

# %%
from diffusers import StableDiffusionPipeline
import torch
import cv2
import os
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
# Initialize Stable Diffusion Pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cuda")  # Use GPU for faster processing
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# ...

# %%
# Video properties
output_folder = "frames"
os.makedirs(output_folder, exist_ok=True)
video_name = "text_to_video.mp4"
frame_width, frame_height = 512, 512
fps = 10
num_frames = 30

# %%
# Text prompt
base_prompt = "A beautiful sunrise over a serene beach, cinematic, vibrant colors"

# %%
# Generate frames
for i in range(num_frames):
    # Modify prompt slightly to simulate movement
    prompt = f"{base_prompt}, perspective {i}"

    # Generate image
    image = pipe(prompt).images[0]
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    image.save(frame_path)
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Combine frames into a video
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video = cv2.VideoWriter(video_name, fourcc, fps, (frame_width, frame_height))

# %%
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    frame = cv2.imread(frame_path)
    video.write(frame)

# %%
video.release()
print(f"Video saved as {video_name}")
# Out:
# Video saved as text_to_video.mp4

# %%
# Clean up frames (optional)
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    os.remove(frame_path)
os.rmdir(output_folder)

# %%
video_name
# Out:
# 'text_to_video.mp4'

# %%
from diffusers import StableDiffusionPipeline
import torch
import cv2
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Initialize Stable Diffusion Pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cuda")  # Use GPU for faster processing

# Video properties
output_folder = "/content/drive/My Drive/frames" # Save frames to Google Drive
os.makedirs(output_folder, exist_ok=True)
video_name = "/content/drive/My Drive/text_to_video.mp4" # Save video to Google Drive
frame_width, frame_height = 512, 512
fps = 10
num_frames = 30

# Text prompt
base_prompt = "A beautiful sunrise over a serene beach, cinematic, vibrant colors"

# Generate frames
for i in range(num_frames):
    # Modify prompt slightly to simulate movement
    prompt = f"{base_prompt}, perspective {i}"

    # Generate image
    image = pipe(prompt).images[0]
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    image.save(frame_path)

# Combine frames into a video
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video = cv2.VideoWriter(video_name, fourcc, fps, (frame_width, frame_height))
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    frame = cv2.imread(frame_path)
    video.write(frame)

video.release()
print(f"Video saved as {video_name}")

# Clean up frames from Google Drive (optional)
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    os.remove(frame_path)
os.rmdir(output_folder)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch
import cv2
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Initialize Stable Diffusion Pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cuda")  # Use GPU for faster processing

# Video properties
output_folder = "/content/drive/My Drive/frames" # Save frames to Google Drive
os.makedirs(output_folder, exist_ok=True)
video_name = "/content/drive/My Drive/text_to_video2.mp4" # Save video to Google Drive
frame_width, frame_height = 512, 512
fps = 10
num_frames = 30

# Text prompt
base_prompt = "A futuristic city with flying cars and neon-lit skyscrapers at night"

# Generate frames
for i in range(num_frames):
    # Modify prompt slightly to simulate movement
    prompt = f"{base_prompt}, perspective {i}"

    # Generate image
    image = pipe(prompt).images[0]
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    image.save(frame_path)

# Combine frames into a video
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video = cv2.VideoWriter(video_name, fourcc, fps, (frame_width, frame_height))
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    frame = cv2.imread(frame_path)
    video.write(frame)

video.release()
print(f"Video saved as {video_name}")

# Clean up frames from Google Drive (optional)
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    os.remove(frame_path)
os.rmdir(output_folder)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Video saved as /content/drive/My Drive/text_to_video2.mp4

# %%
from diffusers import StableDiffusionPipeline
import torch
import cv2
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Initialize Stable Diffusion Pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cuda")  # Use GPU for faster processing

# Video properties
output_folder = "/content/drive/My Drive/frames" # Save frames to Google Drive
os.makedirs(output_folder, exist_ok=True)
video_name = "/content/drive/My Drive/text_to_video3.mp4" # Save video to Google Drive
frame_width, frame_height = 512, 512
fps = 10
num_frames = 30

# Text prompt
base_prompt = "Aishwarya Rai going for holiday to Maldives"

# Generate frames
for i in range(num_frames):
    # Modify prompt slightly to simulate movement
    prompt = f"{base_prompt}, perspective {i}"

    # Generate image
    image = pipe(prompt).images[0]
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    image.save(frame_path)

# Combine frames into a video
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video = cv2.VideoWriter(video_name, fourcc, fps, (frame_width, frame_height))
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    frame = cv2.imread(frame_path)
    video.write(frame)

video.release()
print(f"Video saved as {video_name}")

# Clean up frames from Google Drive (optional)
for i in range(num_frames):
    frame_path = os.path.join(output_folder, f"frame_{i:03d}.png")
    os.remove(frame_path)
os.rmdir(output_folder)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...
